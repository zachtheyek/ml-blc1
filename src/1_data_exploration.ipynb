# %%
# Generate dataset
# %run /datax/scratch/zachy/ml-blc1/signal_modeling/generate.py /datax/scratch/zachy/ml-blc1/data/v1 60000 40000

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Function to count the number of .npy files in a directory
def file_count(path):
    count = len(glob.glob1(path, '*.npy'))
    return count
    
# Function to display (and save) dynamic spectra
def plot_img(path, save=False, clear=False):
    plt.imshow(np.load(path, allow_pickle=True), aspect='auto', interpolation='none'); plt.colorbar()
    if save:
        plt.savefig(f'{path[:-4]}.eps')
    if clear:
        plt.clf()

# %%
# Set path to data
path = '/datax/scratch/zachy/ml-blc1/data/v1'

# %%
# Expected count: 60,000
train_count = file_count(f'{path}/train')
print(f'Number of .npy files in train: {train_count}')

# Expected count: 40,000
test_count = file_count(f'{path}/test')
print(f'Number of .npy files in test: {test_count}')
# Out:
# Number of .npy files in train: 60000
# Number of .npy files in test: 40000

# %%
# Read labels.csv
train_labels = pd.read_csv(f'{path}/train/labels.csv')
test_labels = pd.read_csv(f'{path}/test/labels.csv')

# %%
train_labels
# Out:
#        label   class        snr  start_index  direction    filename
# 0          0  random        NaN          NaN        NaN  000000.npy
# 1          0  random        NaN          NaN        NaN  000001.npy
# 2          0  random        NaN          NaN        NaN  000002.npy
# 3          0  random        NaN          NaN        NaN  000003.npy
# 4          1  target  21.762861        462.0       -1.0  000004.npy
# ...      ...     ...        ...          ...        ...         ...
# 59995      0  random        NaN          NaN        NaN  059995.npy
# 59996      1  target  20.940989        154.0       -1.0  059996.npy
# 59997      0  random        NaN          NaN        NaN  059997.npy
# 59998      0  random        NaN          NaN        NaN  059998.npy
# 59999      1  target  98.373772        120.0        1.0  059999.npy
#
# [60000 rows x 6 columns]

# %%
test_labels
# Out:
#        label     class        snr  start_index  direction    filename
# 0          1    target  98.565059        228.0        1.0  000000.npy
# 1          1    target  84.793869        184.0        1.0  000001.npy
# 2          0  vertical        NaN          NaN        NaN  000002.npy
# 3          1    target  25.813055        499.0       -1.0  000003.npy
# 4          0  vertical        NaN          NaN        NaN  000004.npy
# ...      ...       ...        ...          ...        ...         ...
# 39995      0  vertical        NaN          NaN        NaN  039995.npy
# 39996      1    target  31.012583         87.0        1.0  039996.npy
# 39997      0    random        NaN          NaN        NaN  039997.npy
# 39998      0    random        NaN          NaN        NaN  039998.npy
# 39999      0  vertical        NaN          NaN        NaN  039999.npy
#
# [40000 rows x 6 columns]

# %%
# Test 1
plot_img(f'{path}/train/000000.npy')

# %%
# Test 2
plot_img(f'{path}/train/031777.npy')

# %%
# Test 3
plot_img(f'{path}/test/003009.npy')
